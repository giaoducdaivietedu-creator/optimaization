# %%
# !git clone https://github.com/tydeptrai21042004/Temp_run_all
# Out:
# Cloning into 'Temp_run_all'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 76 (delta 22), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (76/76), 39.75 KiB | 3.97 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# %cd  /content/Temp_run_all
# Out:
# /content/Temp_run_all

# %%
# !python run_all.py
# Out:
# [INFO] 2025-12-27 18:40:28 | device=cuda
# [INFO] results_dir=/content/Temp_run_all/results
# [INFO] seeds=[0] | exp=all
# 100% 9.91M/9.91M [00:00<00:00, 12.9MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 339kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 3.17MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 22.3MB/s]
#
# --- [MNIST] Optimizer = ADAM | tuning ---
# [TUNE] ADAM cfg={'lr': 0.03, 'weight_decay': 0.0} val_loss=0.3363 val_acc=0.9089
# [TUNE] ADAM cfg={'lr': 0.03, 'weight_decay': 0.0001} val_loss=0.3882 val_acc=0.8927
# [TUNE] ADAM cfg={'lr': 0.01, 'weight_decay': 0.0} val_loss=0.3116 val_acc=0.9135
# [TUNE] ADAM cfg={'lr': 0.01, 'weight_decay': 0.0001} val_loss=0.3137 val_acc=0.9117
# [TUNE] ADAM cfg={'lr': 0.003, 'weight_decay': 0.0} val_loss=0.3859 val_acc=0.9003
# [TUNE] ADAM cfg={'lr': 0.003, 'weight_decay': 0.0001} val_loss=0.3834 val_acc=0.8983
# [TUNE] ADAM cfg={'lr': 0.001, 'weight_decay': 0.0} val_loss=0.5987 val_acc=0.8664
# ...
